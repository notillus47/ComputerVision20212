# %%
# Boolean Expressions / True and False

# %%
x = 1
y = 2
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
x < y
# Out:
# True

# %%
x <= y
# Out:
# True

# %%
x > y
# Out:
# False

# %%
x >= y
# Out:
# False

# %%
x is y
# Out:
# False

# %%
if(x == 1 and y ==2):
    print("True if a is true and b is true")
# Out:
# True if a is true and b is true

# %%
if(x == 1 or y == 2):
    print("Ture if a is True or b is True")
# Out:
# Ture if a is True or b is True

# %%
if(not x == 2):
    print("True if a is False")
# Out:
# True if a is False

# %%
if(x == 2):
    print("True")
else:
    print("False")
# Out:
# False
