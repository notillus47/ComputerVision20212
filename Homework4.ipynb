# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img=cv2.imread('book.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[330,301], [901,290], [470,1223],[951,995]])
pts2 = np.float32([[0,0], [800,0], [0,1100],[800,1100]])

M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(800,1100))

plt.rcParams["figure.figsize"]=(20,10)

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')

plt.show()

# %%
img=cv2.imread('book.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[0,0], [901,290], [470,1223],[951,995]])
pts2 = np.float32([[0,0], [900,270], [250,1200],[900,1180]])

M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(1280,1280))

plt.rcParams["figure.figsize"]=(20,10)

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')

plt.show()
