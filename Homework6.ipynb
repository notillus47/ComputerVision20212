# %% [markdown]
# # Homework 6

# %% [markdown]
# ### Implement SIFT feature matching with camera

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img_template = cv2.imread('book4.jpg', cv2.IMREAD_GRAYSCALE) # queryImage
img_template = cv2.resize(img_template, dsize=(640, 480))
cap = cv2.VideoCapture(0)

# %%
while cap.isOpened():
    ret, frame = cap.read()
    img2 = frame[0:500, 0:500]
    
    # Initiate SIFT detector
    sift = cv2.SIFT_create()
    
    # find the keypoints and descriptors with SIFT
    kp1, des1 = sift.detectAndCompute(img_template, None)
    kp2, des2 = sift.detectAndCompute(img2, None)

    # create 
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des1, des2, k=2)
    
    good = []
    for m,n in matches:
        if m.distance < 0.5*n.distance:
            good.append([m])
        
    # cv2.drawMatchesKnn expects list of lists as matches
    img3 = cv2.drawMatchesKnn(img_template, kp1, img2, kp2, good, None, flags=2)
    
    cv2.imshow("result", img3)
    
    key = cv2.waitKey(1)
    if key == 27:
        break

cap.release()
cv2.destroyAllWindows()
