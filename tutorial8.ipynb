# %% [markdown]
# # Functions in Python

# %%
# def get_final_answer(filename):
#     """Documentation String"""
#     line1
#     line2
#     return total_counter

# %%
def myfun(x, y):
    return x*y

# %%
myfun(3,4)
# Out:
# 12

# %%
def myfun(x):
    return x*5

# %%
def apply(q,x):
    return q(x)

# %%
apply(myfun, 7)
# Out:
# 35

# %%
apply(lambda z: z*4, 7)
# Out:
# 28

# %%
def myfun(b, c=3, d="Hi"):
    return b+c

# %%
myfun(5,3,"hi")
# Out:
# 8

# %%
myfun(5,3)
# Out:
# 8

# %%
myfun(7)
# Out:
# 10

# %%
def myfun(a, b,c):
    return a-b
